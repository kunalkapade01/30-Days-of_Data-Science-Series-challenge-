# %% [markdown]
# # Random Forest:

# %%
# Import libraries:
import pandas as pd
import numpy as np

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt

# %%
#Example data:
data = {
    "Age": [25, 45, 35, 50, 23, 34, 32, 28, 40, 27],
    "Income": ["High", "High", "High", "Medium", "Low", "Low", "Low", "Medium", "Low", "Medium"],
    "Student": ["No", "No", "No", "No", "Yes", "Yes", "Yes", "Yes", "Yes", "No"],
    "Buys_computer": ["No", "No", "Yes", "Yes", "Yes", "No", "Yes", "No", "Yes", "Yes"]
}

# %%
# Create a Dataframe:
df = pd.DataFrame(data)

# %%
df
# Out:
#    Age  Income Student Buys_computer
# 0   25    High      No            No
# 1   45    High      No            No
# 2   35    High      No           Yes
# 3   50  Medium      No           Yes
# 4   23     Low     Yes           Yes
# 5   34     Low     Yes            No
# 6   32     Low     Yes           Yes
# 7   28  Medium     Yes            No
# 8   40     Low     Yes           Yes
# 9   27  Medium      No           Yes

# %%
# Convert a categorical features to numeric:
df["Income"] = df["Income"].map({"Low": 1, "Medium": 2, "High": 3})
df["Student"] = df["Student"].map({"No": 0, "Yes": 1})
df["Buys_computer"] = df["Buys_computer"].map({"No": 0, "Yes": 1})

# %%
# Independent variables and dependent variable (features) & (target):
x = df[["Age", "Income", "Student"]]
y = df["Buys_computer"]

# %%
x
# Out:
#    Age  Income  Student
# 0   25       3        0
# 1   45       3        0
# 2   35       3        0
# 3   50       2        0
# 4   23       1        1
# 5   34       1        1
# 6   32       1        1
# 7   28       2        1
# 8   40       1        1
# 9   27       2        0

# %%
y
# Out:
# 0    0
# 1    0
# 2    1
# 3    1
# 4    1
# 5    0
# 6    1
# 7    0
# 8    1
# 9    1
# Name: Buys_computer, dtype: int64

# %%
# Spliting the data into train and test:
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
# Creating and training Decision tree model:
model = DecisionTreeClassifier(criterion='gini', max_depth=3, random_state=12)
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=12)

# %%
#prediction:
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([0, 1], dtype=int64)

# %%
# Evaluting the model:
Accuracy = accuracy_score(y_pred, y_test)
conf_matrix = confusion_matrix(y_pred, y_test)
class_report = classification_report(y_pred, y_test)
# Out:
# C:\Users\kunal\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\kunal\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\kunal\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
print(f"Accuracy Score: {Accuracy}")
print(f"Confusion matrix: \n{conf_matrix}")
print(f"Classification Report: \n{class_report}")
# Out:
# Accuracy Score: 0.5
# Confusion matrix:
# [[0 1]
#  [0 1]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.50      1.00      0.67         1
#
#     accuracy                           0.50         2
#    macro avg       0.25      0.50      0.33         2
# weighted avg       0.25      0.50      0.33         2

# %%
#ploting the Decision tree:
plt.figure(figsize=(8, 4))
plot_tree(model, feature_names=["Age", "Income", "Student"], class_names=["No", "Yes"], 
         filled=True)
plt.title("Decision Tree")
plt.show()
