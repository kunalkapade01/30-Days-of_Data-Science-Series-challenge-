# %% [markdown]
# # - 𝐑𝐞𝐜𝐮𝐫𝐫𝐞𝐧𝐭 𝐍𝐞𝐮𝐫𝐚𝐥 𝐍𝐞𝐭𝐰𝐨𝐫𝐤𝐬 (𝐑𝐍𝐍𝐬) :

# %%
# Import necesary libary :
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense
from sklearn.preprocessing import MinMaxScaler
# Out:
# WARNING:tensorflow:From C:\Users\kunal\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Generate synthetic sequential data.
data = np.sin(np.linspace(0, 100, 1000))

# %%
data
# Out:
# array([ 0.00000000e+00,  9.99330162e-02,  1.98865536e-01,  2.95807081e-01,
#         3.89787104e-01,  4.79864709e-01,  5.65138069e-01,  6.44753455e-01,
#         7.17913784e-01,  7.83886601e-01,  8.42011406e-01,  8.91706275e-01,
#         9.32473678e-01,  9.63905466e-01,  9.85686954e-01,  9.97600074e-01,
#         9.99525555e-01,  9.91444120e-01,  9.73436677e-01,  9.45683512e-01,
#         9.08462478e-01,  8.62146222e-01,  8.07198446e-01,  7.44169268e-01,
#         6.73689717e-01,  5.96465408e-01,  5.13269488e-01,  4.24934884e-01,
#         3.32345974e-01,  2.36429728e-01,  1.38146426e-01,  3.84800478e-02,
#        -6.15715795e-02, -1.61006773e-01, -2.58830020e-01, -3.54061947e-01,
#        -4.45749125e-01, -5.32973611e-01, -6.14862143e-01, -6.90594881e-01,
#        -7.59413613e-01, -8.20629350e-01, -8.73629220e-01, -9.17882606e-01,
#        -9.52946458e-01, -9.78469728e-01, -9.94196886e-01, -9.99970476e-01,
# ...

# %%
# Prapare the dataseta :
def create_dataset(data, time_step=1):
    X, y = [], []
    for i in range(len(data) - time_step - 1):
        a = data[i:(i + time_step)]
        X.append(a)
        y.append(data[i + time_step])
    return np.array(X), np.array(y)

# %%
# Scale the data :
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data.reshape(-1, 1))

# %%
# Create the datsets with time steps :
time_step = 10
X, y = create_dataset(data, time_step)
X = X.reshape(X.shape[0], X.shape[1], 1)

# %%
# split the data into train & test sets :
train_size = int(len(X) * 0.8)
x_train, x_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# %%
# Create the RNN model :
model = Sequential([
    SimpleRNN(50, input_shape=(time_step, 1)),
    Dense(1)
])
# Out:
# WARNING:tensorflow:From C:\Users\kunal\anaconda3\Lib\site-packages\keras\src\layers\rnn\simple_rnn.py:130: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.

# %%
# Compile the model :
model.compile(optimizer="adam", loss="mean_squared_error")
# Out:
# WARNING:tensorflow:From C:\Users\kunal\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# Train the model :
model.fit(x_train, y_train, epochs=50, batch_size=1, verbose=1)
# Out:
# Epoch 1/50
# WARNING:tensorflow:From C:\Users\kunal\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 791/791 [==============================] - 6s 4ms/step - loss: 0.0119
# Epoch 2/50
# 791/791 [==============================] - 3s 4ms/step - loss: 4.8732e-04
# Epoch 3/50
# 791/791 [==============================] - 3s 4ms/step - loss: 1.5995e-04
# Epoch 4/50
# 791/791 [==============================] - 3s 4ms/step - loss: 2.4545e-04
# Epoch 5/50
# 791/791 [==============================] - 3s 4ms/step - loss: 2.6297e-04
# Epoch 6/50
# 791/791 [==============================] - 3s 4ms/step - loss: 3.5978e-05
# Epoch 7/50
# 791/791 [==============================] - 3s 4ms/step - loss: 1.5627e-04
# Epoch 8/50
# 791/791 [==============================] - 3s 4ms/step - loss: 3.1742e-05
# Epoch 9/50
# ...

# %%
# Evalute the model :
loss = model.evaluate(x_test, y_test, verbose=0)
print(f"𝐓𝐞𝐬𝐭 𝐋𝐨𝐬𝐬: {loss}")
# Out:
# 𝐓𝐞𝐬𝐭 𝐋𝐨𝐬𝐬: 4.461307071323972e-06

# %%
# Predict the next value in the sequence :
last_seq = x_test[-1].reshape(1, time_step, 1)
pred_value = model.predict(last_seq)
pred_value = scaler.inverse_transform(pred_value)
print(f"𝐏𝐫𝐞𝐝𝐢𝐜𝐭𝐞𝐝 𝐕𝐚𝐥𝐮𝐞: {pred_value[0][0]}")
# Out:
# 1/1 [==============================] - 0s 441ms/step
# 𝐏𝐫𝐞𝐝𝐢𝐜𝐭𝐞𝐝 𝐕𝐚𝐥𝐮𝐞: -0.5874745845794678

# %% [markdown]
# - 𝐄𝐱𝐚𝐦𝐩𝐥𝐞 𝐰𝐢𝐭𝐡 𝐋𝐒𝐓𝐌

# %%
# Example with LSTM :
from tensorflow.keras.layers import LSTM

# %%
# Create a LSTM model :
model = Sequential([
    LSTM(50, input_shape=(time_step, 1)),
    Dense(1)
])

# %%
# So, same as a before compile, train and evalute the model..
model.compile(optimizer="adam", loss="mean_squared_error")

# %%
model.fit(x_train, y_train, epochs=50, batch_size=1, verbose=1)
# Out:
# Epoch 1/50
# 791/791 [==============================] - 8s 5ms/step - loss: 0.0190
# Epoch 2/50
# 791/791 [==============================] - 4s 5ms/step - loss: 2.1792e-04
# Epoch 3/50
# 791/791 [==============================] - 4s 6ms/step - loss: 2.4539e-04
# Epoch 4/50
# 791/791 [==============================] - 5s 6ms/step - loss: 7.3428e-05
# Epoch 5/50
# 791/791 [==============================] - 5s 6ms/step - loss: 2.0074e-04
# Epoch 6/50
# 791/791 [==============================] - 4s 5ms/step - loss: 9.4568e-05
# Epoch 7/50
# 791/791 [==============================] - 4s 6ms/step - loss: 1.4010e-04
# Epoch 8/50
# 791/791 [==============================] - 4s 5ms/step - loss: 3.3242e-05
# Epoch 9/50
# 791/791 [==============================] - 4s 5ms/step - loss: 2.2162e-05
# Epoch 10/50
# 791/791 [==============================] - 4s 5ms/step - loss: 9.6798e-05
# Epoch 11/50
# 791/791 [==============================] - 5s 6ms/step - loss: 2.6647e-05
# Epoch 12/50
# ...

# %%
loss = model.evaluate(x_test, y_test, verbose=0)
print(f"𝐓𝐞𝐬𝐭 𝐋𝐨𝐬𝐬: {loss}")
# Out:
# 𝐓𝐞𝐬𝐭 𝐋𝐨𝐬𝐬: 3.9161051290648174e-07

# %% [markdown]
# - 𝐂𝐨𝐧𝐜𝐞𝐩𝐭 :
#
# 𝐑𝐞𝐜𝐮𝐫𝐫𝐞𝐧𝐭 𝐍𝐞𝐮𝐫𝐚𝐥 𝐍𝐞𝐭𝐰𝐨𝐫𝐤𝐬 (𝐑𝐍𝐍𝐬)are a class of neural networks designed to recognize patterns in sequences of data such as time series, natural language, or video frames. Unlike traditional neural networks, RNNs have connections that form directed cycles, allowing them to maintain a hidden state that can capture information about previous inputs.

# %% [markdown]
# 𝐊𝐞𝐲 𝐅𝐞𝐚𝐭𝐮𝐫𝐞𝐬 𝐨𝐟 𝐑𝐍𝐍𝐬 :
#
# - 𝐒𝐞𝐪𝐮𝐞𝐧𝐭𝐢𝐚𝐥 𝐃𝐚𝐭𝐚 𝐏𝐫𝐨𝐜𝐞𝐬𝐬𝐢𝐧𝐠: Designed to handle sequences of varying lengths.
# - 𝐇𝐢𝐝𝐝𝐞𝐧 𝐒𝐭𝐚𝐭𝐞: Maintains information about previous elements in the sequence.
# - 𝐒𝐡𝐚𝐫𝐞𝐝 𝐖𝐞𝐢𝐠𝐡𝐭𝐬: Uses the same weights across all time steps, reducing the number of parameters.
# - 𝐕𝐚𝐧𝐢𝐬𝐡𝐢𝐧𝐠/𝐄𝐱𝐩𝐥𝐨𝐝𝐢𝐧𝐠 𝐆𝐫𝐚𝐝𝐢𝐞𝐧𝐭 𝐏𝐫𝐨𝐛𝐥𝐞𝐦: Can struggle with long-term dependencies due to these issues.

# %% [markdown]
# 𝐊𝐞𝐲 𝐒𝐭𝐞𝐩𝐬 :
#
# - 𝐈𝐧𝐩𝐮𝐭 𝐚𝐧𝐝 𝐇𝐢𝐝𝐝𝐞𝐧 𝐒𝐭𝐚𝐭𝐞𝐬: Each input element is processed along with the hidden state from the previous time step.
# - 𝐑𝐞𝐜𝐮𝐫𝐫𝐞𝐧𝐭 𝐂𝐨𝐧𝐧𝐞𝐜𝐭𝐢𝐨𝐧𝐬: The hidden state is updated recursively.
# - 𝐎𝐮𝐭𝐩𝐮𝐭 𝐋𝐚𝐲𝐞𝐫: Produces predictions based on the hidden state at each time step.

# %% [markdown]
# 𝐊𝐞𝐲 𝐒𝐭𝐞𝐩𝐬 :
#
# - 𝐈𝐧𝐩𝐮𝐭 𝐚𝐧𝐝 𝐇𝐢𝐝𝐝𝐞𝐧 𝐒𝐭𝐚𝐭𝐞𝐬: Each input element is processed along with the hidden state from the previous time step.
# - 𝐑𝐞𝐜𝐮𝐫𝐫𝐞𝐧𝐭 𝐂𝐨𝐧𝐧𝐞𝐜𝐭𝐢𝐨𝐧𝐬: The hidden state is updated recursively.
# - 𝐎𝐮𝐭𝐩𝐮𝐭 𝐋𝐚𝐲𝐞𝐫: Produces predictions based on the hidden state at each time step.

# %% [markdown]
# 𝐀𝐝𝐯𝐚𝐧𝐜𝐞𝐝 𝐅𝐞𝐚𝐭𝐮𝐫𝐞𝐬 𝐨𝐟 𝐑𝐍𝐍𝐬 :
#
# 1. 𝐋𝐒𝐓𝐌 (𝐋𝐨𝐧𝐠 𝐒𝐡𝐨𝐫𝐭-𝐓𝐞𝐫𝐦 𝐌𝐞𝐦𝐨𝐫𝐲): Designed to handle long-term dependencies better than vanilla RNNs.
# 2. 𝐆𝐑𝐔 (𝐆𝐚𝐭𝐞𝐝 𝐑𝐞𝐜𝐮𝐫𝐫𝐞𝐧𝐭 𝐔𝐧𝐢𝐭): A simplified version of LSTM with similar performance.
# 3. 𝐁𝐢𝐝𝐢𝐫𝐞𝐜𝐭𝐢𝐨𝐧𝐚𝐥 𝐑𝐍𝐍𝐬: Process the sequence in both forward and backward directions.
# 4. 𝐒𝐭𝐚𝐜𝐤𝐞𝐝 𝐑𝐍𝐍𝐬: Use multiple layers of RNNs for better feature extraction.
# 5. 𝐀𝐭𝐭𝐞𝐧𝐭𝐢𝐨𝐧 𝐌𝐞𝐜𝐡𝐚𝐧𝐢𝐬𝐦𝐬: Improve the model's ability to focus on important parts of the sequence.

# %% [markdown]
# 𝐀𝐩𝐩𝐥𝐢𝐜𝐚𝐭𝐢𝐨𝐧𝐬...
#
# RNNs are widely used in various fields such as:
# - 𝐍𝐚𝐭𝐮𝐫𝐚𝐥 𝐋𝐚𝐧𝐠𝐮𝐚𝐠𝐞 𝐏𝐫𝐨𝐜𝐞𝐬𝐬𝐢𝐧𝐠 (𝐍𝐋𝐏): Language modeling, machine translation, text generation.
# - 𝐓𝐢𝐦𝐞 𝐒𝐞𝐫𝐢𝐞𝐬 𝐀𝐧𝐚𝐥𝐲𝐬𝐢𝐬: Stock price prediction, weather forecasting, anomaly detection.
# - 𝐒𝐩𝐞𝐞𝐜𝐡 𝐑𝐞𝐜𝐨𝐠𝐧𝐢𝐭𝐢𝐨𝐧: Transcribing spoken language into text.
# - 𝐕𝐢𝐝𝐞𝐨 𝐀𝐧𝐚𝐥𝐲𝐬𝐢𝐬: Activity recognition, video captioning.
# - 𝐌𝐮𝐬𝐢𝐜 𝐆𝐞𝐧𝐞𝐫𝐚𝐭𝐢𝐨𝐧: Composing music by predicting sequences of notes.

# %% [markdown]
# - 𝐑𝐍𝐍𝐬' 𝐚𝐛𝐢𝐥𝐢𝐭𝐲 𝐭𝐨 𝐜𝐚𝐩𝐭𝐮𝐫𝐞 𝐭𝐞𝐦𝐩𝐨𝐫𝐚𝐥 𝐝𝐞𝐩𝐞𝐧𝐝𝐞𝐧𝐜𝐢𝐞𝐬 𝐦𝐚𝐤𝐞𝐬 𝐭𝐡𝐞𝐦 𝐡𝐢𝐠𝐡𝐥𝐲 𝐞𝐟𝐟𝐞𝐜𝐭𝐢𝐯𝐞 𝐟𝐨𝐫 𝐬𝐞𝐪𝐮𝐞𝐧𝐭𝐢𝐚𝐥 𝐝𝐚𝐭𝐚 𝐭𝐚𝐬𝐤𝐬.
